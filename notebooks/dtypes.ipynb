# %%
import pandas as pd

# %%
data = pd.read_csv('../data/gas_chromatography.csv', sep=';', encoding='latin-1')
data
# Out:
#      Compound ID               Compound name  \
# 0        C100005  Benzene, 1-chloro-4-nitro-
# 1        C100005  Benzene, 1-chloro-4-nitro-
# 2        C100005  Benzene, 1-chloro-4-nitro-
# 3        C100005  Benzene, 1-chloro-4-nitro-
# 4        C100005  Benzene, 1-chloro-4-nitro-
# ...          ...                         ...
# 1276     C100414                Ethylbenzene
# 1277     C100414                Ethylbenzene
# 1278     C100414                Ethylbenzene
# 1279     C100414                Ethylbenzene
# 1280     C100414                Ethylbenzene
#
#                                                  InChI Retention index type  \
# 0     InChI=1S/C6H4ClNO2/c7-5-1-3-6(4-2-5)8(9)10/h1-4H             Lee's RI
# 1     InChI=1S/C6H4ClNO2/c7-5-1-3-6(4-2-5)8(9)10/h1-4H     Normal alkane RI
# 2     InChI=1S/C6H4ClNO2/c7-5-1-3-6(4-2-5)8(9)10/h1-4H     Normal alkane RI
# 3     InChI=1S/C6H4ClNO2/c7-5-1-3-6(4-2-5)8(9)10/h1-4H     Normal alkane RI
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1281 entries, 0 to 1280
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Compound ID           1281 non-null   object
#  1   Compound name         1281 non-null   object
#  2   InChI                 1281 non-null   object
#  3   Retention index type  1281 non-null   object
#  4   Column polarity       1281 non-null   object
#  5   Active phase          1281 non-null   object
#  6   Carrier gas           834 non-null    object
#  7   Temperature regime    1278 non-null   object
#  8   I                     1278 non-null   float64
#  9   Temperature           397 non-null    object
#  10  Tstart                548 non-null    float64
#  11  Tend                  531 non-null    float64
#  12  Heat rate             547 non-null    object
#  13  Initial hold          305 non-null    object
#  14  Final hold            242 non-null    object
# ...

# %%
data['Compound ID'].value_counts(dropna=False)
# Out:
# Compound ID
# C100414       544
# C1002842      116
# C10032152      80
# C100185        55
# C1003298       50
#              ...
# C1002944        1
# C1003174        1
# C10027073       1
# C1003561        1
# C100347964      1
# Name: count, Length: 66, dtype: int64

# %%
data.isna().sum().sort_values(ascending=False).head(10)
# Out:
# Substrate          1180
# Final hold         1039
# Initial hold        976
# Program             955
# Temperature         884
# Tend                750
# Heat rate           734
# Tstart              733
# Phase thickness     623
# Carrier gas         447
# dtype: int64
